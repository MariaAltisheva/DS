# %% [markdown]
# # Визуализация.

# %% [markdown]
# Датасет представляет собой коллекцию медицинских и демографических данных пациентов, а также их статус диабета (положительный или отрицательный). Данные включают такие характеристики, как возраст, пол, индекс массы тела (ИМТ), гипертония, сердечно-сосудистые заболевания, история курения, уровень HbA1c и уровень глюкозы в крови.
#
# В будущем этот датасет может быть использован для построения моделей машинного обучения для прогнозирования диабета у пациентов на основе их истории болезни и демографической информации. Это может быть полезно для медицинских работников при выявлении пациентов, которые могут быть подвержены риску развития диабета, и при разработке персонализированных планов лечения.
#
# Описание столбцов:
#
# |Название| Описание |
# |--|--|
# |`gender`| Пол пациента |
# |`age`| Возраст |
# |`hypertension`| Гипертония —  это состояние, при котором кровяное давление в артериях постоянно повышено. Он принимает значения 0 или 1, где 0 означает отсутствие гипертонии, а 1 —  наличие гипертонии. |
# |`heart_disease`| Болезни сердца —  это еще одно состояние, которое связано с повышенным риском развития диабета. Он также принимает значения 0 или 1, где 0 означает отсутствие сердечных заболеваний, а 1 —  наличие сердечных заболеваний. |
# |`smoking_history`| Опыт курения —  также считается фактором риска развития диабета и может усугубить осложнения, связанные с диабетом. |
# |`bmi`| Это показатель количества жира в организме, основанный на весе и росте. Более высокие значения ИМТ связаны с повышенным риском развития диабета. Диапазон ИМТ в наборе данных составляет от 10,16 до 71,55. ИМТ менее 18,5 —  это недостаточный вес, 18,5-24,9 —  нормальный, 25-29,9 —  избыточный вес, а 30 и более —  ожирение. |
# |`HbA1c_level`| Уровень HbA1c (гемоглобин A1c) —  это показатель среднего уровня сахара в крови человека за последние 2-3 месяца. Более высокий уровень указывает на больший риск развития диабета. В основном более 6,5% уровня HbA1c указывает на диабет. |
# |`blood_glucose_level`| Уровень глюкозы в крови —  это количество глюкозы в крови в определенный момент времени. Высокий уровень глюкозы в крови является основным признаком диабета. |
# |`diabetes`| Диабет является целевой переменной (таргетом), при этом значение 1 указывает на наличие диабета, а 0 —  на его отсутствие. |

# %% [markdown]
# ## Задание
#
# Проведите визуализацию данных и попробуйте выяснить причины, от чего и с чем связаны основные причины наличия диабета у людей.
#
# Ваша цель —  визуально с помощью графиков определить и доказать, что при наличии какого-либо фактора возможен риск развития диабета.
#
# Этапы выполнения задания (наш pipeline):
#
# 1. Загрузка и предобработка данных (при необходимости)
# 2. Описательный анализ данных, просмотр данных
# 3. Построение гистограмм числовых переменных
# 4. Построение диаграмм размаха для определения наличия выбросов (ящики с усами) числовых переменных
# 5. Построение столбчатых диаграмм для категориальных переменных
# 6. Построение матрицы корреляции признаков (Phik или Пирсона)
# 7. Сравнение двух выборок
# 8. Общий вывод

# %% [markdown]
# ## Загрузка данных

# %%
# !pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('diabetes_prediction_dataset.csv')

# %%
df
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %% [markdown]
# ## Описательный анализ данных

# %% [markdown]
# Рассмотрите данные —  изучите медианы, средние, дисперсии и т.д.
#
# Что можете сказать о данных? Сделайте вывод.

# %%
df.describe()
# Out:
#                  age  hypertension  heart_disease            bmi  \
# count  100000.000000  100000.00000  100000.000000  100000.000000
# mean       41.885856       0.07485       0.039420      27.320767
# std        22.516840       0.26315       0.194593       6.636783
# min         0.080000       0.00000       0.000000      10.010000
# 25%        24.000000       0.00000       0.000000      23.630000
# 50%        43.000000       0.00000       0.000000      27.320000
# 75%        60.000000       0.00000       0.000000      29.580000
# max        80.000000       1.00000       1.000000      95.690000
#
#          HbA1c_level  blood_glucose_level       diabetes
# count  100000.000000        100000.000000  100000.000000
# mean        5.527507           138.058060       0.085000
# std         1.070672            40.708136       0.278883
# min         3.500000            80.000000       0.000000
# 25%         4.800000           100.000000       0.000000
# ...

# %% [markdown]
# **Вывод:**
# 1. Охват аудитории по возрасту составляет от 0 до 80 лет. Соответственно, если мы будет делат какие-то выводы, строить модели, то данные инструменты будут актуальны для людей соответсвующего возраста 0-80. Для людей старше 80 лет могут уже быть допущены существенные погрешности.
# 2. Средний возраст составляет 41,9, а медиана - 43 года. Это хороший показатель. Значит относиельно возрастного признака данные подобраны равномерно.
# 3. Из представленных пациентов - 7,5 процентов гипертоников, 3,9 процентов имеют болезни сердца, 8,5 процентов диабетиков. То есть большинство пациентов являются здоровыми людьми. Возможно, но пока рано об этом говорить, будет смысл сокращать датасет для определенных выводов или исследований. Например, если нам потребуются данные только тех людей, которые страдают от болезней сердца и сталкивались с ожирением, то здоровые пациенты нам будут неинтересны. Мы сможем построить модель на основании которой, будем предсказывать, болен ли новый пациент с болезнями сердца и ожирением (не из нашего датасета) диабетом, или же это маловероятно. Если мы изучаем пациентов с болезнями сердца и ожирением.
# 4. Индекс массы тела (медианный и средний) практически равны, значит по данному параметру данные распределены равномерно.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Дубликаты

# %% [markdown]
# Предобработайте датасет —  проверьте на наличие дубликатов и удалите, если они есть.

# %%
df.duplicated().sum()
# Out:
# 3854

# %% [markdown]
# Из 100 000 строк у нас имеется 3854 дубликата, их целесообразно удалить и перезаписать.

# %%
df.drop_duplicates(inplace=True)

# %%
# Проверяю, что они действительно удалились
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Отсутствующие значения

# %% [markdown]
# Предобработайте датасет — проверьте на наличие NaN и удалите или заполните значения.

# %%
df.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64

# %%
count_no_info = df[df['smoking_history'] == 'No info'].shape[0]
count_no_info
# Out:
# 0

# %% [markdown]
# Неявные пропуски и NaN отсутствуют

# %% [markdown]
# ### Изменение типа данных

# %% [markdown]
# Рассмотрев все данные, замените типы на нужные (при необходимости):
#
# - Если есть числа — на `int` или `float`
# - Если категории — можно оставить `object`

# %%
df.dtypes# ваш код здесь
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %% [markdown]
# **Вывод:**
# Типы данных оптимальны для визуализации и дальнейшего исследования.

# %% [markdown]
# ## Визуализация

# %% [markdown]
# Построим графики:
#
# 1. Построение гистограмм числовых переменных
# 2. Построение диаграмм размаха для определения наличия выбросов (ящики с усами) числовых переменных
# 3. Построение столбчатых диаграмм для категориальных переменных
# 4. Построение матрицы корреляции признаков (Phik или Пирсона)
#
# После построения опишите выборку. Что она из себя представляет? Есть ли зависимости?

# %%
# гистограмма зависимости возраста от количества пациентов
plt.figure(figsize=(6, 4))
sns.histplot(df['age'], bins=20, kde=True, color='Red')
plt.title('Количество пациентов по возрастам')
plt.xlabel('Возраст')
plt.ylabel('Количество')
plt.show()

# %%
# гистограмма для bmi
plt.figure(figsize=(6,4))
sns.histplot(df['bmi'], bins=20, kde=True, color='Green')
plt.title('Распределение по индексу bmi')
plt.xlabel('BMI')
plt.ylabel('Количество')
plt.show()

# %%
# Гистограмма для переменной HbA1c_level
plt.figure(figsize=(6,4))
sns.histplot(df['HbA1c_level'], bins=20, kde=True, color='Pink')
plt.title('Распределение по HbAlc_level')
plt.xlabel('HbA1c Level')
plt.ylabel('Количество')
plt.show()

# %%
# Гистограмма по уровню глюкозы в крови
plt.figure(figsize=(6, 4))
sns.histplot(df['blood_glucose_level'], bins=20, kde=True, color='Red')
plt.title('Распределение уровня глюкозы в крови по количеству пациентов')
plt.xlabel('Уровень глюкозы в крови')
plt.ylabel('Количество')
plt.show()

# %%
# Диаграмма размаха для данных по возрасту
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['age'], color='Grey')
plt.title('Диаграмма размаха для данных по возрасту')
plt.xlabel('Возраст')
plt.show()

# %%
# Диаграмма размаха для индекса веса
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['bmi'], color='Pink')
plt.title('Диаграмма размаха для данных по bmi')
plt.xlabel('bmi')
plt.show()

# %%
# Диаграмма размаха для HbA1c_level
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['HbA1c_level'], color='Darkgreen')
plt.title('Диаграмма размаха для данных по HbA1c_level')
plt.xlabel('HbA1c_level')
plt.show()

# %%
# Диаграмма размаха для blood_glucose_level
plt.figure(figsize=(5, 3))
sns.boxplot(x=df['blood_glucose_level'], color='Red')
plt.title('Диаграмма размаха для данных по blood_glucose_level')
plt.xlabel('blood_glucose_level')
plt.show()

# %%
# Столбчатая диаграмма распределений пациентов по половому признаку
plt.figure(figsize=(6, 4))
sns.countplot(x='gender', data=df, color = 'darkred')
plt.title('Диаграмма распределений пациентов по половому признаку')
plt.xlabel('blood_glucose_level')
plt.show()

# %%
# Диаграмма распределений пациентов по наличию гипертонии
plt.figure(figsize=(6, 4))
sns.countplot(x='hypertension', data=df, color = 'darkred')
plt.title('Диаграмма распределений пациентов по наличию гипертонии')
plt.xlabel('наличие гипертонии')
plt.ylabel('количество')
plt.show()

# %%
# Столбчатая диаграмма для переменной heart_disease
plt.figure(figsize=(6, 4))
sns.countplot(x='heart_disease', data=df, color = 'darkred')
plt.title('Диаграмма распределений пациентов по наличию заболеваний сердца')
plt.xlabel('наличие заболеваний сердца')
plt.ylabel('количество')
plt.show()

# %%
# Столбчатая диаграмма для переменной smoking_history
plt.figure(figsize=(6, 4))
sns.countplot(x='smoking_history', data=df)
plt.title('Диаграмма распределений пациентов по параметрам курения')
plt.xlabel('параметр курения')
plt.ylabel('количество')
plt.show()

# %%
# Столбчатая диаграмма для переменной diabetes
plt.figure(figsize=(6, 4))
sns.countplot(x='diabetes', data=df, color='darkred')
plt.title('Диаграмма распределений пациентов по диагностированному диабету')
plt.xlabel('диабет')
plt.ylabel('количество')
plt.show()

# %%
# Матрица корелляции Пирсона
new_df = df.drop('gender', axis=1, inplace=False) # строки с полом и историей курения я удалила и перезаписала в другую переменную
new_df = new_df.drop('smoking_history', axis=1, inplace=False)
tmp = new_df.corr()
plt.figure(figsize=(7,7))
sns.heatmap(tmp, annot=True, cmap='Greens')
plt.imshow(tmp)
plt.title('Матрица корелляции Пирсона')
plt.show()

# %% [markdown]
# **Вывод:**
# 1. Большинство пациентов, люди возраста 80 лет. Также можно заметить, что в районе 50 лет много пациентов. Я думаю тут можно сделать вывод о том, что в данном возрасле (50 и 80 лет) у людей пик болезней и они чаще обращаются за помощью к врачам. Если брать значение 0 лет, то я думаю это связано с тем, что практически всех младенцев проверяют на диабет.
# 2. Большинтсво пациентов имеют индект BMI в районе 30.
# 3. Большинство пациентов имеют показатель HbA1c Level в районе 6-7.
# 4. Чаще всего обращались к врачам женщины. Уже многими исследованиями доказано, что женщины в большей мере следят за своим здоровьем.
# 5. Большнство пациентов не страдает от гипертонии, а также у малого количсетва обнаружены заболевания сердца. Большинство никгда не курило. Скорее всего анализировалось некое достаточно здоровое общество.

# %% [markdown]
# ## Сравнение выборок

# %% [markdown]
# После построения всех типов графиков, необходимо провести анализ:
#
# Отобразите на одном графике две выборки — люди с диабетом и без и сравните их.
#
# 1. Для числовых признаков — гистограммы и ящики с усами.
# 2. Для категориальных — столбчатые диаграммы.
#
# После напишите вывод, есть ли какая-то зависимость?

# %%
# гистограммы для числовых признаков
numerical_features = ['age', 'bmi', 'HbA1c_level', 'blood_glucose_level']
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))
axes = axes.flatten()

for i, feature in enumerate(numerical_features):
    sns.histplot(data=df, x=feature, hue='diabetes', kde=True, ax=axes[i])
    axes[i].set_title(f'Histogram of {feature}')

plt.tight_layout()
plt.show()

# %%
# Ящики диаграмм для числовых признаков
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))
axes = axes.flatten()

for i, feature in enumerate(numerical_features):
    sns.boxplot(data=df, x='diabetes', y=feature, ax=axes[i])
    axes[i].set_title(f'Boxplot of {feature}')

plt.tight_layout()
plt.show()

# %%
# Столбчатые диаграммы для категориальных признаков
categorical_features = ['gender', 'hypertension', 'heart_disease', 'smoking_history']
fig, axes = plt.subplots(nrows=2, ncols=2, figsize = (8, 6))
axes = axes.flatten()

for i, feature in enumerate(categorical_features):
    sns.countplot(data=df, x=feature, hue='diabetes', ax=axes[i])
    axes[i].set_title(f'Countplot of {feature}')
    axes[i].legend(title='diabetes', loc='upper right')

plt.tight_layout()
plt.show()
# plt.save()

# %% [markdown]
# **Вывод:**
#
# Основной вывод, который я могла бы тут сделать, это то, что данная категория пациентов является достаточно здоровой. Большинство не курит и никогда не пробовало. У подавляющего большинства отсутствуют болезни сердца, гипертония и диабет. И при этом большнство пациентов представляют возрастные группы 50 и 80 лет.
# Скорее всего это данные некой развитой страны, где развито здравоохранение и ведется здоровый образ жизни.

# %% [markdown]
# ## ЗАДАЧИ PRO

# %% [markdown]
# Мы провели базовый анализ выше и сделали выводы.
#
# Но даёт ли этот результат полную картину? Наша цель — узнать, каков риск возникновения диабета у пациента.
#
# Ваша задача — воспользоваться ранее приобретенными навыками и дополнить общий вывод.
#
# **Этапы:**
#
# 1) Разделите выборки и постройте дополнительные графики. Может стоит разделить на несколько выборок и сравнить графики там?
# 2) Постройте `pairplot` с параметром `hue=='diabetes'`. Может там тоже где-то кроется истина?
# 2) Постройте тепловую карту корреляции `Phik` и сделайте дополнительный вывод.
# 3) Дополните общий вывод.
#
# **Примечание:** задание не ограничено только этими этапами. Можно их дополнить — может стоит сделать фильтр данных, рассмотреть данные под другим углом и провести дополнительную аналитику? Средствами и методами не ограничены.

# %%
# ваш код здесь

# %% [markdown]
# # Общий вывод

# %% [markdown]
# Опишите данные и результат исследования, основываясь на предыдущих шагах:
